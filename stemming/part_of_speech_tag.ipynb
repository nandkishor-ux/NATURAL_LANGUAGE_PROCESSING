# %%
paragraph="""The old mahogany clock tower in the center of town finally chimed thirteen times, a strange, resonant sound that echoed through the empty streets, signaling the dawn of an unusual Tuesday. While most residents remained nestled in their beds, Elias stood on his balcony, observing the surreal scene with a cup of lukewarm coffee in hand. A sudden, vibrant streak of teal light shot across the early morning sky, leaving behind a subtle, shimmering trail that seemed to hum with energy. He watched as the neighborhood trees suddenly bloomed, their leaves turning from a pale morning green to a dazzling, iridescent violet in mere seconds, confounding the local squirrels who chattered frantically. The air smelled intensely of jasmine and metallic dust, a combination that made his nose twitch involuntarily. He contemplated waking his wife, but the scene was far too serene to interrupt, and the world seemed, for once, to hold its breath. Even the traffic lights on Main Street began to blink in a non-linear, rhythmic sequence that suggested a new, forgotten language. It was a bizarre, untethered moment that hung in the silence between dreams and reality, a reminder that the world could still surprise even those who believed they had seen everything life had to offer."""

# %%
import nltk
from nltk.corpus import stopwords
sentences=nltk.sent_tokenize(paragraph)
sentences
# Out:
# ['The old mahogany clock tower in the center of town finally chimed thirteen times, a strange, resonant sound that echoed through the empty streets, signaling the dawn of an unusual Tuesday.',
#  'While most residents remained nestled in their beds, Elias stood on his balcony, observing the surreal scene with a cup of lukewarm coffee in hand.',
#  'A sudden, vibrant streak of teal light shot across the early morning sky, leaving behind a subtle, shimmering trail that seemed to hum with energy.',
#  'He watched as the neighborhood trees suddenly bloomed, their leaves turning from a pale morning green to a dazzling, iridescent violet in mere seconds, confounding the local squirrels who chattered frantically.',
#  'The air smelled intensely of jasmine and metallic dust, a combination that made his nose twitch involuntarily.',
#  'He contemplated waking his wife, but the scene was far too serene to interrupt, and the world seemed, for once, to hold its breath.',
# ...

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
## we will find pos tags
import nltk

# Download required data (run once)
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt')
nltk.download('stopwords')

from nltk.corpus import stopwords

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [word for word in words if word not in set(stopwords.words('english'))]
    pos_tags = nltk.pos_tag(words)  
    print(pos_tags)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [('The', 'DT'), ('old', 'JJ'), ('mahogany', 'NN'), ('clock', 'NN'), ('tower', 'NN'), ('center', 'NN'), ('town', 'NN'), ('finally', 'RB'), ('chimed', 'VBD'), ('thirteen', 'JJ'), ('times', 'NNS'), (',', ','), ('strange', 'JJ'), (',', ','), ('resonant', 'JJ'), ('sound', 'NN'), ('echoed', 'VBD'), ('empty', 'JJ'), ('streets', 'NNS'), (',', ','), ('signaling', 'VBG'), ('dawn', 'NN'), ('unusual', 'JJ'), ('Tuesday', 'NNP'), ('.', '.')]
# ...
