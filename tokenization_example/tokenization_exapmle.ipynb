# %%
corpus="""
hello welcome to shuvam nlp totorial .
i am learning this from udemy .
and i am enjioying it a lot .
"""

# %%
print(corpus)

# %%
import subprocess
subprocess.run(["pip", "install", "nltk"])

# %%
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')  # needed in newer NLTK versions

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
print(documents)

# %%
##tokenization 
## paragraphs - words
## sentence - words

from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)

# %%
for sentences in documents:
    print(word_tokenize(sentences))

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
from nltk.tokenize import TreebankWordDetokenizer
## fulll stop and comma are treated as separate tokens in word_tokenize
## but in wordpunct_tokenize they are not treated as separate tokens
## only the last full stop is treated as separate token in wordpunct_tokenize
## but in word_tokenize all the full stops are treated as separate tokens
